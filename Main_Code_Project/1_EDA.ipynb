# %%
# Importing Libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt  
from matplotlib.colors import LinearSegmentedColormap

# %%
#Load the Data
gaji_bersih = pd.read_excel(r'C:\Users\adinr\Documents\Python_Project-3_Minimum Wage\Python_Project-3_Minimum-Wage\Data_of_Interest_Cleaned\gaji_bersih_persektor.xlsx')
output_per_hour = pd.read_excel(r'C:\Users\adinr\Documents\Python_Project-3_Minimum Wage\Python_Project-3_Minimum-Wage\Data_of_Interest_Cleaned\filtered_output_per_hour_global_interest.xlsx')
upah_minimum_regional_indonesia = pd.read_excel(r'C:\Users\adinr\Documents\Python_Project-3_Minimum Wage\Python_Project-3_Minimum-Wage\Data_of_Interest_Cleaned\upah_minimum_regional.xlsx')
minimum_wage_global_interest = pd.read_excel(r'C:\Users\adinr\Documents\Python_Project-3_Minimum Wage\Python_Project-3_Minimum-Wage\Data_of_Interest_Cleaned\minimum_wage_global_interest.xlsx')

# %%
gaji_bersih
# Out:
#           Provinsi  Pertanian_Kehutanan_Perikanan  Pertambangan_Penggalian  \
# 0             Aceh                   1.770893e+06             4.319690e+06
# 1   Sumatera Utara                   2.075633e+06             2.508242e+06
# 2   Sumatera Barat                   2.133080e+06             3.563619e+06
# 3            Riau                    2.312776e+06             3.794517e+06
# 4            Jambi                   1.873694e+06             2.374643e+06
# ..             ...                            ...                      ...
# 63  Sulawesi Barat                   1.922346e+06             1.340724e+06
# 64          Maluku                   1.498867e+06             2.388702e+06
# 65    Maluku Utara                   1.581105e+06             5.176584e+06
# 66     Papua Barat                   2.123166e+06             5.550903e+06
# 67           Papua                   3.240955e+06             9.039489e+06
#
#     Industri_Pengolahan  Pengadaan_Listrik_Gas  \
# 0          1.582935e+06           4.739714e+06
# 1          2.376736e+06           4.352666e+06
# 2          4.796867e+06           2.897159e+06
# 3          3.063291e+06           3.252059e+06
# 4          2.286682e+06           2.314218e+06
# ..                  ...                    ...
# 63         1.856440e+06           2.454993e+06
# 64         1.869387e+06           4.001955e+06
# 65         3.099635e+06           3.543639e+06
# 66         2.787723e+06           4.148262e+06
# 67         3.404589e+06           4.270126e+06
#
#     Pengadaan_Air_Pengelolaan_Sampah_Limbah_Daur_Ulang    Konstruksi  \
# 0                                        2.613734e+06   2.018182e+06
# 1                                        2.958524e+06   2.399140e+06
# 2                                        2.660929e+06   2.269822e+06
# 3                                        2.613734e+06   2.935918e+06
# 4                                        2.307544e+06   2.804188e+06
# ..                                                ...            ...
# 63                                       9.606780e+05   1.887013e+06
# 64                                       1.597583e+06   2.134369e+06
# 65                                       2.518553e+06   2.721686e+06
# 66                                       3.684250e+06   2.913599e+06
# 67                                       2.877074e+06   4.078937e+06
#
#     Perdagangan_Besar_Eceran_Reparasi_Perawatan_Mobil_Motor  \
# 0                                        1.770988e+06
# 1                                        2.130970e+06
# 2                                        2.096998e+06
# 3                                        2.222780e+06
# 4                                        1.928621e+06
# ..                                                ...
# 63                                       1.275630e+06
# 64                                       2.315172e+06
# 65                                       2.408254e+06
# 66                                       2.269340e+06
# 67                                       3.164933e+06
#
#     Transportasi_Pergudangan  Penyediaan_Akomodasi_Makan_Minum  ...  \
# 0               2.166686e+06                      1.623484e+06  ...
# 1               2.373657e+06                      1.828837e+06  ...
# 2               2.270564e+06                      1.549011e+06  ...
# 3               2.729953e+06                      1.748250e+06  ...
# 4               2.435928e+06                      2.034758e+06  ...
# ..                       ...                               ...  ...
# 63              2.266442e+06                      1.145403e+06  ...
# 64              2.056470e+06                      1.623476e+06  ...
# 65              2.240865e+06                      1.739586e+06  ...
# 66              3.356173e+06                      2.545050e+06  ...
# 67              3.104367e+06                      3.033273e+06  ...
#
#     Jasa_Keuangan_Asuransi    Real_Estat  Jasa_Perusahaan  \
# 0             3.765889e+06  2.946183e+06     2.756137e+06
# 1             3.424562e+06  2.946183e+06     2.577315e+06
# 2             3.725653e+06  2.946183e+06     1.821342e+06
# 3             3.474215e+06  2.311194e+06     2.295867e+06
# 4             4.104933e+06  2.946183e+06     2.155028e+06
# ..                     ...           ...              ...
# 63            3.011557e+06  2.946183e+06     2.109226e+06
# 64            3.430403e+06  2.946183e+06     2.031937e+06
# 65            3.654644e+06  2.946183e+06     2.098469e+06
# 66            4.681673e+06  2.946183e+06     3.519015e+06
# 67            4.452882e+06  2.946183e+06     3.791785e+06
#
#     Administrasi_Pemerintahan_Pertahanan_Jaminan_Sosial_Wajib  \
# 0                                        3.402898e+06
# 1                                        3.429228e+06
# 2                                        3.298905e+06
# 3                                        3.833548e+06
# 4                                        2.658997e+06
# ..                                                ...
# 63                                       3.160635e+06
# 64                                       3.697977e+06
# 65                                       3.330390e+06
# 66                                       3.691222e+06
# 67                                       4.388419e+06
#
#     Jasa_Pendidikan  Jasa_Kesehatan_Kegiatan_Sosial  Jasa_Lainnya  \
# 0      2.463639e+06                    2.351776e+06  9.381317e+05
# 1      2.580750e+06                    2.901284e+06  1.247901e+06
# 2      2.730290e+06                    2.691128e+06  1.657335e+06
# 3      2.495425e+06                    3.346704e+06  1.166727e+06
# 4      2.270354e+06                    1.960737e+06  1.135453e+06
# ..              ...                             ...           ...
# 63     2.335598e+06                    1.937262e+06  1.031277e+06
# 64     2.765409e+06                    2.405911e+06  1.570655e+06
# 65     2.793471e+06                    2.297209e+06  2.190482e+06
# 66     3.153749e+06                    2.850512e+06  2.455944e+06
# 67     3.457605e+06                    3.649670e+06  2.499333e+06
#
#           Jumlah      Tahun Month
# 0   2.317419e+06 2021-02-01     2
# 1   2.402795e+06 2021-02-01     2
# 2   2.831081e+06 2021-02-01     2
# 3   2.732853e+06 2021-02-01     2
# 4   2.219533e+06 2021-02-01     2
# ..           ...        ...   ...
# 63  2.200963e+06 2021-08-01     8
# 64  2.676833e+06 2021-08-01     8
# 65  2.996268e+06 2021-08-01     8
# 66  3.239125e+06 2021-08-01     8
# 67  3.949649e+06 2021-08-01     8
#
# [68 rows x 21 columns]

# %% [markdown]
# # Descriptive Statistics

# %%
minimum_wage_global_interest[minimum_wage_global_interest['ref_area.label'] == 'Indonesia']
# Out:
#    ref_area.label          classif1.label  time  obs_value
# 55      Indonesia  Currency: U.S. dollars  2023    321.706
# 56      Indonesia  Currency: U.S. dollars  2022    180.461
# 57      Indonesia  Currency: U.S. dollars  2021    174.956
# 58      Indonesia  Currency: U.S. dollars  2020    171.668
# 59      Indonesia  Currency: U.S. dollars  2019    111.037
# 60      Indonesia  Currency: U.S. dollars  2018    102.140
# 61      Indonesia  Currency: U.S. dollars  2017     99.967
# 62      Indonesia  Currency: U.S. dollars  2016     93.002
# 63      Indonesia  Currency: U.S. dollars  2015     82.154
# 64      Indonesia  Currency: U.S. dollars  2013    127.365
# 65      Indonesia  Currency: U.S. dollars  2012    119.223
# 66      Indonesia  Currency: U.S. dollars  2011    112.742
# 67      Indonesia  Currency: U.S. dollars  2010     99.973
# 68      Indonesia  Currency: U.S. dollars  2009     79.952
# 69      Indonesia  Currency: U.S. dollars  2008     76.627
# 70      Indonesia  Currency: U.S. dollars  2007     73.066
# 71      Indonesia  Currency: U.S. dollars  2006     65.747
# 72      Indonesia  Currency: U.S. dollars  2005     52.315
# 73      Indonesia  Currency: U.S. dollars  2004     51.293
# 74      Indonesia  Currency: U.S. dollars  2003     48.350
# 75      Indonesia  Currency: U.S. dollars  2002     38.953
# 76      Indonesia  Currency: U.S. dollars  2001     28.311
# 77      Indonesia  Currency: U.S. dollars  2000     25.707
# 78      Indonesia  Currency: U.S. dollars  1999     22.329
# 79      Indonesia  Currency: U.S. dollars  1998     15.069
# 80      Indonesia  Currency: U.S. dollars  1997     46.402
# 81      Indonesia  Currency: U.S. dollars  1996     50.690
# 82      Indonesia  Currency: U.S. dollars  1995     45.962

# %%
output_per_hour[output_per_hour['ref_area.label'] == 'Indonesia']
# Out:
#    ref_area.label  time  obs_value
# 21      Indonesia  2025      15.70
# 22      Indonesia  2024      15.12
# 23      Indonesia  2023      14.59
# 24      Indonesia  2022      14.10
# 25      Indonesia  2021      14.25
# 26      Indonesia  2020      13.37
# 27      Indonesia  2019      13.24
# 28      Indonesia  2018      12.95
# 29      Indonesia  2017      12.28
# 30      Indonesia  2016      11.94
# 31      Indonesia  2015      11.49
# 32      Indonesia  2014      11.28
# 33      Indonesia  2013      11.30
# 34      Indonesia  2012      10.35
# 35      Indonesia  2011       9.93
# 36      Indonesia  2010       9.47
# 37      Indonesia  2009       9.26
# 38      Indonesia  2008       9.03
# 39      Indonesia  2007       8.65
# 40      Indonesia  2006       8.57
# 41      Indonesia  2005       8.32

# %%
print("Descriptive Statistics for Gaji Bersih:")
gaji_bersih.describe()
# Out:
# Descriptive Statistics for Gaji Bersih:
#        Pertanian_Kehutanan_Perikanan  Pertambangan_Penggalian  \
# count                   6.800000e+01             6.800000e+01
# mean                    2.006769e+06             4.008643e+06
# min                     1.102850e+06             9.671841e+05
# 25%                     1.621087e+06             2.651007e+06
# 50%                     1.913288e+06             3.626604e+06
# 75%                     2.330194e+06             4.958363e+06
# max                     3.564155e+06             9.039489e+06
# std                     5.164172e+05             1.892081e+06
#
#        Industri_Pengolahan  Pengadaan_Listrik_Gas  \
# count         6.800000e+01           6.800000e+01
# mean          2.514615e+06           3.815128e+06
# min           1.182504e+06           1.736622e+06
# 25%           1.842110e+06           3.017307e+06
# 50%           2.348179e+06           3.754760e+06
# 75%           3.022847e+06           4.161995e+06
# max           5.036621e+06           8.821346e+06
# std           9.043526e+05           1.266405e+06
#
#        Pengadaan_Air_Pengelolaan_Sampah_Limbah_Daur_Ulang    Konstruksi  \
# count                                       6.800000e+01   6.800000e+01
# mean                                        2.613734e+06   2.639192e+06
# min                                         9.606780e+05   1.602819e+06
# 25%                                         2.135475e+06   2.163595e+06
# 50%                                         2.544410e+06   2.378719e+06
# 75%                                         2.939571e+06   2.771635e+06
# max                                         5.414785e+06   6.269189e+06
# std                                         8.118740e+05   8.165533e+05
#
#        Perdagangan_Besar_Eceran_Reparasi_Perawatan_Mobil_Motor  \
# count                                       6.800000e+01
# mean                                        2.215461e+06
# min                                         1.274064e+06
# 25%                                         1.916753e+06
# 50%                                         2.085671e+06
# 75%                                         2.514731e+06
# max                                         3.676470e+06
# std                                         5.270579e+05
#
#        Transportasi_Pergudangan  Penyediaan_Akomodasi_Makan_Minum  \
# count              6.800000e+01                      6.800000e+01
# mean               2.769806e+06                      1.819063e+06
# min                1.303945e+06                      7.773301e+05
# 25%                2.250747e+06                      1.532063e+06
# 50%                2.564740e+06                      1.627421e+06
# 75%                3.093874e+06                      2.010532e+06
# max                6.359719e+06                      4.543503e+06
# std                8.449674e+05                      6.126299e+05
#
#        Informasi_Komunikasi  Jasa_Keuangan_Asuransi    Real_Estat  \
# count          6.800000e+01            6.800000e+01  6.800000e+01
# mean           3.028995e+06            3.938203e+06  2.946183e+06
# min            1.351961e+06            2.371993e+06  1.245810e+06
# 25%            2.309519e+06            3.263061e+06  2.507400e+06
# 50%            2.738405e+06            3.834079e+06  2.946183e+06
# 75%            3.503498e+06            4.458278e+06  2.946183e+06
# max            6.041489e+06            5.983174e+06  5.288266e+06
# std            1.083094e+06            8.179540e+05  6.971681e+05
#
#        Jasa_Perusahaan  \
# count     6.800000e+01
# mean      2.702183e+06
# min       1.193541e+06
# 25%       2.095301e+06
# 50%       2.390719e+06
# 75%       3.235531e+06
# max       7.340720e+06
# std       9.585483e+05
#
#        Administrasi_Pemerintahan_Pertahanan_Jaminan_Sosial_Wajib  \
# count                                       6.800000e+01
# mean                                        3.794855e+06
# min                                         2.658997e+06
# 25%                                         3.309711e+06
# 50%                                         3.651076e+06
# 75%                                         4.137976e+06
# max                                         6.267323e+06
# std                                         7.507485e+05
#
#        Jasa_Pendidikan  Jasa_Kesehatan_Kegiatan_Sosial  Jasa_Lainnya  \
# count     6.800000e+01                    6.800000e+01  6.800000e+01
# mean      2.828890e+06                    3.055945e+06  1.537138e+06
# min       1.831940e+06                    1.591351e+06  5.584257e+05
# 25%       2.405884e+06                    2.524329e+06  1.182827e+06
# 50%       2.779440e+06                    2.849712e+06  1.416820e+06
# 75%       3.156759e+06                    3.355086e+06  1.765903e+06
# max       3.979391e+06                    6.101626e+06  2.797957e+06
# std       4.992913e+05                    9.513321e+05  5.006837e+05
#
#              Jumlah                Tahun      Month
# count  6.800000e+01                   68  68.000000
# mean   2.791845e+06  2021-05-02 12:00:00   5.000000
# min    1.942230e+06  2021-02-01 00:00:00   2.000000
# 25%    2.335631e+06  2021-02-01 00:00:00   2.000000
# 50%    2.630607e+06  2021-05-02 12:00:00   5.000000
# 75%    3.095027e+06  2021-08-01 00:00:00   8.000000
# max    4.302611e+06  2021-08-01 00:00:00   8.000000
# std    5.955020e+05                  NaN   3.022305

# %%
print("\nDescriptive Statistics for Output per Hour:")
print(output_per_hour.describe())

print("\nDescriptive Statistics for Upah Minimum Regional:")
print(upah_minimum_regional_indonesia.describe())

print("\nDescriptive Statistics for Minimum Wage:")
print(minimum_wage_global_interest.describe())
# Out:
# Descriptive Statistics for Output per Hour:
#               time   obs_value
# count   294.000000  294.000000
# mean   2015.000000   26.691395
# std       6.065625   24.943266
# min    2005.000000    1.970000
# 25%    2010.000000    7.262500
# 50%    2015.000000   13.095000
# 75%    2020.000000   48.235000
# max    2025.000000   96.880000
#
# Descriptive Statistics for Upah Minimum Regional:
#                2019          2020
# count  3.500000e+01  3.500000e+01
# mean   2.455662e+06  2.672371e+06
# std    5.014104e+05  5.428615e+05
# min    1.570923e+06  1.704608e+06
# 25%    2.226385e+06  2.415850e+06
# 50%    2.400664e+06  2.672371e+06
# 75%    2.767608e+06  3.003132e+06
# max    3.940973e+06  4.276350e+06
#
# Descriptive Statistics for Minimum Wage:
#               time    obs_value
# count   342.000000   342.000000
# mean   2010.222222   506.921731
# std       8.004235   684.645478
# min    1995.000000     0.011000
# 25%    2003.250000    59.354500
# 50%    2011.000000   147.318500
# 75%    2017.000000   858.233500
# max    2023.000000  2720.781000

# %%
merged_data = pd.merge(output_per_hour, minimum_wage_global_interest, 
                       left_on=['ref_area.label', 'time'], 
                       right_on=['ref_area.label', 'time'], 
                       suffixes=('_output', '_wage'))

plt.figure(figsize=(10, 6))
sns.scatterplot(x='obs_value_output', y='obs_value_wage', data=merged_data)
plt.title('Scatter Plot of Output per Hour vs Minimum Wage')
plt.xlabel('Output per Hour (GDP constant 2021 international $ at PPP)')
plt.ylabel('Minimum Wage (Rupiah)')
plt.show()

# %%
merged_data
# Out:
#     ref_area.label  time  obs_value_output          classif1.label  \
# 0        Australia  2023             67.84  Currency: U.S. dollars
# 1        Australia  2022             68.41  Currency: U.S. dollars
# 2        Australia  2021             68.59  Currency: U.S. dollars
# 3        Australia  2020             70.11  Currency: U.S. dollars
# 4        Australia  2019             67.63  Currency: U.S. dollars
# ..             ...   ...               ...                     ...
# 220       Viet Nam  2009              5.57  Currency: U.S. dollars
# 221       Viet Nam  2008              5.36  Currency: U.S. dollars
# 222       Viet Nam  2007              5.17  Currency: U.S. dollars
# 223       Viet Nam  2006              5.01  Currency: U.S. dollars
# 224       Viet Nam  2005              4.86  Currency: U.S. dollars
#
#      obs_value_wage
# 0          2460.163
# 1          2442.020
# 2          2514.928
# 3          2247.953
# 4          2231.574
# ..              ...
# 220          38.090
# 221          33.124
# 222          33.530
# 223          28.135
# 224          22.070
#
# [225 rows x 5 columns]

# %%
minimum_wage_global_interest
# Out:
#     ref_area.label          classif1.label  time  obs_value
# 0        Australia  Currency: U.S. dollars  2023   2460.163
# 1        Australia  Currency: U.S. dollars  2022   2442.020
# 2        Australia  Currency: U.S. dollars  2021   2514.928
# 3        Australia  Currency: U.S. dollars  2020   2247.953
# 4        Australia  Currency: U.S. dollars  2019   2231.574
# ..             ...                     ...   ...        ...
# 337       Viet Nam  Currency: U.S. dollars  2004     18.417
# 338       Viet Nam  Currency: U.S. dollars  2003     18.698
# 339       Viet Nam  Currency: U.S. dollars  2002     13.744
# 340       Viet Nam  Currency: U.S. dollars  2001     12.224
# 341       Viet Nam  Currency: U.S. dollars  2000     12.705
#
# [342 rows x 4 columns]

# %%
# Line plot for minimum_wage_global_interest with time as X and obs_value as Y grouped by ref_area.label
plt.figure(figsize=(10,6))
for label, df in minimum_wage_global_interest.groupby('ref_area.label'):
    plt.plot(df['time'], df['obs_value'], label=label)
plt.title('Minimum Wage Over Time by Country')
plt.xlabel('Time')
plt.ylabel('Obs Value')
plt.legend()
plt.show()

# %%
# Ensure the 'time' column is kept as an integer
output_per_hour['time'] = output_per_hour['time'].astype(int)

# Line plot for obs_value_output with time as X and obs_value as Y
plt.figure(figsize=(10,6))
for label, df in output_per_hour.groupby('ref_area.label'):
    plt.plot(df['time'], df['obs_value'], label=label)
plt.title('Output per Hour Over Time by Country')
plt.xlabel('Time')
plt.ylabel('Obs Value')
plt.xticks(df['time'], df['time'].astype(int), rotation=45)
plt.legend()
plt.show()

# %%
output_per_hour['time'] = output_per_hour['time'].astype(int)
output_per_hour
# Out:
#     ref_area.label  time  obs_value
# 0        Australia  2025      69.19
# 1        Australia  2024      68.20
# 2        Australia  2023      67.84
# 3        Australia  2022      68.41
# 4        Australia  2021      68.59
# ..             ...   ...        ...
# 289       Viet Nam  2009       5.57
# 290       Viet Nam  2008       5.36
# 291       Viet Nam  2007       5.17
# 292       Viet Nam  2006       5.01
# 293       Viet Nam  2005       4.86
#
# [294 rows x 3 columns]

# %%
# Calculate CAGR (Compound Annual Growth Rate) from minimum_wage_global_interest and obs_value_output from merged data
def calculate_cagr(start_value,end_value,time_periods):
    return (end_value/start_value)**(1/time_periods)-1

# Initialize lists to store CAGR values
cagr_wage_list = []
cagr_output_list = []
countries = []

# Calculate CAGR for each country
for label, df in merged_data.groupby('ref_area.label'):
    start_value_wage = df['obs_value_wage'].iloc[-1]
    end_value_wage = df['obs_value_wage'].iloc[0]
    periods_wage = len(df['time'].unique()) -1
    cagr_wage = calculate_cagr(start_value_wage,end_value_wage,time_periods=periods_wage)
    
    start_value_output = df['obs_value_output'].iloc[-1]
    end_value_output = df['obs_value_output'].iloc[0]
    periods_output = len(df['time'].unique()) -1
    cagr_output = calculate_cagr(start_value_output,end_value_output,time_periods=periods_output)
    
    cagr_wage_list.append(cagr_wage * 100) # Convert to percentage
    cagr_output_list.append(cagr_output * 100) # Convert to percentage
    countries.append(label)

# Create a DataFrame for CAGR values
cagr_data = {
    "Country": countries,
    "CAGR Minimum Wage": cagr_wage_list,
    "CAGR Output per Hour": cagr_output_list
}

cagr_df = pd.DataFrame(cagr_data)

# Visualize the CAGR values grouped by countries
plt.figure(figsize=(12,6))
cagr_df.set_index('Country').plot(kind='bar')
plt.title("CAGR (Compound Annual Growth Rate) Comparison by Country")
plt.ylabel("CAGR (%)")
plt.xticks(rotation=45)
plt.show()

# %%
merged_data['ref_area.label'].value_counts()
# Out:
# ref_area.label
# Australia      19
# India          19
# Japan          19
# Cambodia       19
# South Korea    19
# Laos           19
# New Zealand    19
# Philippines    19
# Thailand       19
# Viet Nam       19
# Indonesia      18
# Malaysia       11
# Myanmar         6
# Name: count, dtype: int64

# %%
output_per_hour['ref_area.label'].value_counts()
# Out:
# ref_area.label
# Australia      21
# Indonesia      21
# India          21
# Japan          21
# Cambodia       21
# South Korea    21
# Laos           21
# Myanmar        21
# Malaysia       21
# New Zealand    21
# Philippines    21
# Singapore      21
# Thailand       21
# Viet Nam       21
# Name: count, dtype: int64

# %%
minimum_wage_global_interest['ref_area.label'].value_counts()
# Out:
# ref_area.label
# China          29
# Japan          29
# South Korea    29
# Philippines    29
# Thailand       29
# Indonesia      28
# Cambodia       27
# New Zealand    27
# Australia      26
# India          24
# Laos           24
# Viet Nam       24
# Malaysia       11
# Myanmar         6
# Name: count, dtype: int64
